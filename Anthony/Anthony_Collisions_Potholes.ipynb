# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from config import gkey
import requests

# %%
file = "../data/pd_collisions_datasd.csv"
df = pd.read_csv(file)
# print(len(df))
# df.drop_duplicates(['lat', 'long', 'district', 'case_origin'], inplace=True)
# print(len(df))
# df = df[df.case_origin != "Letter"]
# df = df[df.case_origin != "Crew/Self Generated"]
# df = df[df.case_origin != "Garage Run"]
# df = df[df.case_origin != "Route Slip"]
# df = df[df.case_origin != "Walk-In"]
# print(len(df))
# df.to_csv("../data/cleaned_output.csv")
df.head()
# Out:
#   report_id    date_time  police_beat  street_no street_dir  street_name  \
# 0    170166  1/1/17 0:01          124       8300             CAM DEL ORO
# 1    170218  1/1/17 0:01          325       8100             ROYAL GORGE
# 2    170101  1/1/17 0:01          322       6400                CRAWFORD
# 3    170082  1/1/17 0:01          935       5500                 VALERIO
# 4    170097  1/1/17 1:00          521       1000                    11TH
#
#   street_type cross_st_dir cross_st_name cross_st_type violation_section  \
# 0                                                               MISC-HAZ
# 1       DRIVE                                                      22107
# 2      STREET                                                   MISC-HAZ
# 3       TRAIL                                                   MISC-HAZ
# 4      AVENUE                                                      22107
#
#   violation_type                                        charge_desc  injured  \
# ...

# %%
df['zip_code'] = ''
df.head()
# Out:
#   report_id    date_time  police_beat  street_no street_dir  street_name  \
# 0    170166  1/1/17 0:01          124       8300             CAM DEL ORO
# 1    170218  1/1/17 0:01          325       8100             ROYAL GORGE
# 2    170101  1/1/17 0:01          322       6400                CRAWFORD
# 3    170082  1/1/17 0:01          935       5500                 VALERIO
# 4    170097  1/1/17 1:00          521       1000                    11TH
#
#   street_type cross_st_dir cross_st_name cross_st_type violation_section  \
# 0                                                               MISC-HAZ
# 1       DRIVE                                                      22107
# 2      STREET                                                   MISC-HAZ
# 3       TRAIL                                                   MISC-HAZ
# 4      AVENUE                                                      22107
#
#   violation_type                                        charge_desc  injured  \
# ...

# %%
params = {"key": gkey}
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

street_no = '8300'
street_name = 'CAM DEL ORO'
street_type = ''
city = 'San Diego'
state = 'CA'

# update address key value
params['address'] = f"{street_no}{street_name}{street_type},{city},{state}"

# make request
address_zips = requests.get(base_url, params=params)

# print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
print(address_zips.url)

address_zips = address_zips.json()
address_zips['results'][0]['address_components'][7]['short_name']
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyCvx99-NGDx4KBZ_cCbUc2Av_XU-ORWOhI&address=8300CAM+DEL+ORO%2CSan+Diego%2CCA
# '92037'

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

print('Beginning Data Retrieval')

# Loop through the cities_pd and run a lat/long search for each city
for index, row in df.iterrows():
    print(f'Processing Record {index}')
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    street_no = row['street_no']
    street_name = row['street_name']
    street_type = row['street_type']
    city = 'San Diego'
    state = 'CA'

    # update address key value
    params['address'] = f"{street_no}{street_name}{street_type},{city},{state}"

    # make request
    address_zips = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(address_zips.url)
    
    # convert to json
    address_zips = address_zips.json()

    try:
        df.loc[index, "zip_code"] = address_zips['results'][0]['address_components'][7]['short_name']
          
    except (KeyError, IndexError):
        print('Zip Code not found. Skipping...')
    
# Visualize to confirm lat lng appear
df.head()
# Out:
# Beginning Data Retrieval
# Processing Record 0
# Processing Record 1
# Processing Record 2
# Processing Record 3
# Processing Record 4
# Zip Code not found. Skipping...
# Processing Record 5
# Processing Record 6
# Processing Record 7
# Zip Code not found. Skipping...
# Processing Record 8
# Processing Record 9
# Processing Record 10
# Processing Record 11
# Zip Code not found. Skipping...
# Processing Record 12
# Processing Record 13
# Processing Record 14
# Processing Record 15
# Zip Code not found. Skipping...
# Processing Record 16
# Processing Record 17
# Processing Record 18
# Processing Record 19
# Processing Record 20
# Processing Record 21
# Processing Record 22
# Processing Record 23
# Processing Record 24
# Processing Record 25
# Processing Record 26
# Processing Record 27
# Processing Record 28
# Zip Code not found. Skipping...
# Processing Record 29
# Processing Record 30
# Zip Code not found. Skipping...
# Processing Record 31
# Processing Record 32
# ...

# %%
df.to_csv("../data/collision_output_pt1.csv")

# %%
units = 'imperial'
url = (f'https://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q=')



print('Beginning Data Retrieval')

for index, row in city_df.iterrows():
    city = row['City']
    time.sleep(1)
    weather = requests.get(url + city).json()

    try:
        print(f'Processing Record {index} | {city}')
        city_df.loc[index, 'Cloudiness'] = weather['clouds']['all']
        city_df.loc[index, 'Country'] = weather['sys']['country']
        city_df.loc[index, 'Date'] = weather['dt']
        city_df.loc[index, 'Humidity'] = weather['main']['humidity']
        city_df.loc[index, 'Lat'] = weather['coord']['lat']
        city_df.loc[index, 'Lng'] = weather['coord']['lon']
        city_df.loc[index, 'Max Temp'] = weather['main']['temp_max']
        city_df.loc[index, 'Wind Speed'] = weather['wind']['speed']
    
    except (KeyError, IndexError):
        print('City not found. Skipping...')
        
print('Data Retrieval Complete')
